# %%
from urllib.request import urlopen
raw_html = urlopen("https://slickdeals.net/").read()

# %%
#49 16 * * * python3 Scraping.ipnyb

# %%
import requests

response = requests.get('https://slickdeals.net/')

# %%
print(type(raw_html))
# Out:
# <class 'bytes'>

# %%
print(raw_html)
# Out:
# b'<!DOCTYPE html>\n<!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\n<!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->\n<!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!--> <html class="no-js"> <!--<![endif]-->\n  <head>\n    <script>var googletag = googletag || {};\n      googletag.cmd = googletag.cmd || [];\n    </script>\n                      \n          \n      <script>\nArray.from||(Array.from=function(){var r=Object.prototype.toString,n=function(n){return"function"==typeof n||"[object Function]"===r.call(n)},t=function(r){var n=Number(r);return isNaN(n)?0:0!==n&&isFinite(n)?(n>0?1:-1)*Math.floor(Math.abs(n)):n},e=Math.pow(2,53)-1,o=function(r){var n=t(r);return Math.min(Math.max(n,0),e)};return function(r){var t=this,e=Object(r);if(null==r)throw new TypeError("Array.from requires an array-like object - not null or undefined");var a,i=arguments.length>1?arguments[1]:void 0;if(void 0!==i){if(!n(
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup_doc = BeautifulSoup(raw_html, "html.parser")
print(type(soup_doc))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
print(soup_doc.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js">
#  <!--<![endif]-->
#  <head>
#   <script>
#    var googletag = googletag || {};
#       googletag.cmd = googletag.cmd || [];
#   </script>
#   <script>
# ...

# %%
soup_doc.title
# Out:
# <title>Slickdeals: The Best Deals, Coupons, Promo Codes &amp; Discounts</title>

# %%
Everything= soup_doc.find_all('a')

# %%
itemtitles= soup_doc.find_all('a',  attrs={'class': 'itemTitle'})

# %%
Items=soup_doc.find_all('a',  attrs={'class': 'itemTitle'})

# %%
soup_doc.find_all('a',  attrs={'class': 'itemTitle'})
# Out:
# [<a class="itemTitle" data-link="dealBlock:Grid Item Title Link" href="" title=""></a>,
#  <a class="itemTitle" data-link="dealBlock:Grid Item Title Link" href="/f/10076220-wells-fargo-cash-wise-visa-card-200-bonus-1-5-cash-rewards?src=sticky" title="Wells Fargo Cash Wise Visa® Card $200 Bonus">Wells Fargo Cash Wise Visa® Card</a>,
#  <a class="itemTitle" data-link="dealBlock:Grid Item Title Link" href="/f/11200259-3-year-nordvpn-subscription-99?src=sticky" title="3-Year NordVPN Subscription $99">3-Year NordVPN Subscription</a>,
#  <a class="itemTitle" data-link="dealBlock:Grid Item Title Link" href="/f/11703283-allen-edmonds-warehouse-sale-men-s-tate-wingtip-shoe-130-more-free-s-h-on-50?src=sticky" title="Allen Edmonds Warehouse Sale: Men's Tate Wingtip Shoe $130">Allen Edmonds Warehouse Sale&amp;colon; Men&amp;apos;s Tate Wingtip Shoe</a>,
# ...

# %%
SaleList= []

for Item in Items:
    if Item.string != "None":
        print(Item.string)
        print("----------")
        SaleList.append(Item.string)
    else:
        pass
# Out:
# None
# ----------
# Wells Fargo Cash Wise Visa® Card
# ----------
# 3-Year NordVPN Subscription
# ----------
# Allen Edmonds Warehouse Sale&colon; Men&apos;s Tate Wingtip Shoe
# ----------
# Chase Sapphire Preferred Credit Card
# ----------
# Chase Ink Business Cash Card
# ----------
# Dewalt Brushless&colon; Cordless String Trimmer &plus; Blower &plus; 4&period;0Ah Batttery
# ----------
# Chase Freedom Unlimited® Credit Card
# ----------
# Chase Ink Business Unlimited Credit Card
# ----------
# Chase Ink Business Preferred Card
# ----------
# Verizon Fios&colon; 100&sol;100 Mbps Internet Only Plan &lpar;New Customers Only&rpar;
# ----------
# EVGA GeForce GTX 1060 Gaming 6GB GDDR5 Graphics Card
# ----------
# Mountain Hardwear Direttissima 35 OutDry Pack
# ----------
# 2-Pack Anker Waterproof Pouch for 6" Smartphones
# ----------
# DuroMax 2000-Watt Dual Fuel Portable Generator
# ----------
# Horizon Zero Dawn&colon; The Frozen Wilds DLC &lpar;PS4 Digital Download&rpar;
# ...

# %%
SaleList
# Out:
# [None,
#  'Wells Fargo Cash Wise Visa® Card',
#  '3-Year NordVPN Subscription',
#  'Allen Edmonds Warehouse Sale&colon; Men&apos;s Tate Wingtip Shoe',
#  'Chase Sapphire Preferred Credit Card',
#  'Chase Ink Business Cash Card',
#  'Dewalt Brushless&colon; Cordless String Trimmer &plus; Blower &plus; 4&period;0Ah Batttery',
#  'Chase Freedom Unlimited® Credit Card',
#  'Chase Ink Business Unlimited Credit Card',
#  'Chase Ink Business Preferred Card',
#  'Verizon Fios&colon; 100&sol;100 Mbps Internet Only Plan &lpar;New Customers Only&rpar;',
#  'EVGA GeForce GTX 1060 Gaming 6GB GDDR5 Graphics Card',
#  'Mountain Hardwear Direttissima 35 OutDry Pack',
#  '2-Pack Anker Waterproof Pouch for 6" Smartphones',
#  'DuroMax 2000-Watt Dual Fuel Portable Generator',
#  'Horizon Zero Dawn&colon; The Frozen Wilds DLC &lpar;PS4 Digital Download&rpar;',
#  'Sapphire Radeon NITRO&plus; RX 580 8GB GDDR5 Video Card',
#  'Battle Chasers&colon; Nightwar &lpar;Nintendo Switch&rpar;',
# ...

# %%
response = requests.post(
        "https://api.KEY",
        auth=("api", "KEY),
        data={"from": "Excited User <zle2105@columbia.edu>",
              "to": ["zle2105@columbia.edu"],
              "subject": "8AM sales report",
              "text": (SaleList) })

# %%
#response.text
