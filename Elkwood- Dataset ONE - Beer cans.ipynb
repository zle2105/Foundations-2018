# %% [markdown]
# # Homework 6, Part One: Lots and lots of questions about beer

# %% [markdown]
# ### Do your importing and your setup

# %%
import pandas as pd

df = pd.read_csv("craftcans.csv")
import matplotlib
# %matplotlib inline

# %% [markdown]
# ## Read in the file `craftcans.csv`, and look at the first first rows

# %%
df.head()
# Out:
#             Beer            Brewery         Location               Style  \
# 0   Get Together  NorthGate Brewing  Minneapolis, MN        American IPA
# 1  Maggie's Leap  NorthGate Brewing  Minneapolis, MN  Milk / Sweet Stout
# 2     Wall's End  NorthGate Brewing  Minneapolis, MN   English Brown Ale
# 3        Pumpion  NorthGate Brewing  Minneapolis, MN         Pumpkin Ale
# 4     Stronghold  NorthGate Brewing  Minneapolis, MN     American Porter
#
#      Size    ABV IBUs
# 0  16 oz.  4.50%   50
# 1  16 oz.  4.90%   26
# 2  16 oz.  4.80%   19
# 3  16 oz.  6.00%   38
# 4  16 oz.  6.00%   25

# %% [markdown]
# ## How many rows do you have in the data? What are the column types?

# %%
df.shape
# Out:
# (2416, 7)

# %%
df.dtypes
# Out:
# Beer        object
# Brewery     object
# Location    object
# Style       object
# Size        object
# ABV         object
# IBUs        object
# dtype: object

# %% [markdown]
# # Checking out our alcohol

# %% [markdown]
# ## What are the top 10 producers of cans of beer?

# %%
df.sort_values(by='IBUs', ascending = False).head(10)
# Out:
#                                   Beer                     Brewery  \
# 732              Graham Cracker Porter         Denver Beer Company
# 1800        Woodchuck Amber Hard Cider        Woodchuck Hard Cider
# 903                      Rudolph's Red  Rivertowne Brewing Company
# 1802  Sea Dog Wild Blueberry Wheat Ale     Sea Dog Brewing Company
# 1803                   Pumpkinhead Ale    Shipyard Brewing Company
# 1804                   Ambitious Lager    Wildwood Brewing Company
# 1806               Cut Throat Pale Ale        Finch's Beer Company
# 894                    12 Man Pale Ale      Dick's Brewing Company
# 1808                     Rail Yard Ale     Wynkoop Brewing Company
# 891                    All Nighter Ale         Banner Beer Company
#
#               Location                                Style    Size    ABV  \
# 732         Denver, CO                      American Porter  12 oz.  5.00%
# 1800    Middlebury, VT                                Cider  12 oz.  5.00%
# ...

# %% [markdown]
# ## What is the most common ABV? (alcohol by volume)

# %%
df.ABV.value_counts().head()
# Out:
# 5.00%    215
# 5.50%    158
# 6.00%    125
# 6.50%    123
# 5.20%    107
# Name: ABV, dtype: int64

# %% [markdown]
# ## Oh, weird, ABV isn't a number. Convert it to a number for me, please.
#
# It's going to take a few steps!
#
# ### First, let's just look at the ABV column by itself

# %%
df.ABV
# Out:
# 0        4.50%
# 1        4.90%
# 2        4.80%
# 3        6.00%
# 4        6.00%
# 5        5.60%
# 6        8.00%
# 7       12.50%
# 8        7.70%
# 9        4.20%
# 10       5.00%
# 11       6.60%
# 12       4.00%
# 13       5.50%
# 14       7.60%
# 15       5.10%
# 16       6.50%
# 17       6.00%
# 18       5.00%
# 19       5.20%
# 20       4.80%
# 21       7.20%
# 22       6.70%
# 23       4.90%
# 24       8.00%
# 25       7.50%
# 26       6.00%
# 27       8.00%
# 28       6.30%
# 29       5.80%
#          ...
# 2386     5.70%
# 2387     6.20%
# 2388     4.90%
# 2389     9.90%
# 2390     6.20%
# 2391     5.80%
# 2392     5.20%
# 2393     8.50%
# 2394     7.00%
# 2395     5.30%
# 2396     5.60%
# 2397     4.90%
# 2398     5.10%
# 2399     4.00%
# 2400     5.50%
# 2401     5.10%
# 2402     5.10%
# 2403     9.70%
# 2404     5.10%
# 2405     6.70%
# 2406     6.20%
# 2407     8.30%
# 2408     7.00%
# 2409     4.90%
# 2410     9.90%
# 2411     5.30%
# 2412     9.90%
# ...

# %% [markdown]
# ### Hm, `%` isn't part of  a number. Let's remove it.
#
# When you're confident you got it right, save the results back into the `ABV` column.
#
# - *Tip: In programming the easiest way to remove something is to *replacing it with nothing*.
# - *Tip: "nothing" might seem like `NaN` sinc we talked about it a lot in class, but in this case it isn't! It's just an empty string, like ""*
# - *Tip: `.replace` is used for replacing ENTIRE cells, while `.str.replace` is useful for replacing PARTS of cells (see my New York example)*

# %%
df.ABV.str.replace("%","",)
# Out:
# 0        4.50
# 1        4.90
# 2        4.80
# 3        6.00
# 4        6.00
# 5        5.60
# 6        8.00
# 7       12.50
# 8        7.70
# 9        4.20
# 10       5.00
# 11       6.60
# 12       4.00
# 13       5.50
# 14       7.60
# 15       5.10
# 16       6.50
# 17       6.00
# 18       5.00
# 19       5.20
# 20       4.80
# 21       7.20
# 22       6.70
# 23       4.90
# 24       8.00
# 25       7.50
# 26       6.00
# 27       8.00
# 28       6.30
# 29       5.80
#         ...
# 2386     5.70
# 2387     6.20
# 2388     4.90
# 2389     9.90
# 2390     6.20
# 2391     5.80
# 2392     5.20
# 2393     8.50
# 2394     7.00
# 2395     5.30
# 2396     5.60
# 2397     4.90
# 2398     5.10
# 2399     4.00
# 2400     5.50
# 2401     5.10
# 2402     5.10
# 2403     9.70
# 2404     5.10
# 2405     6.70
# 2406     6.20
# 2407     8.30
# 2408     7.00
# 2409     4.90
# 2410     9.90
# 2411     5.30
# 2412     9.90
# 2413     8.00
# 2414     8.70
# 2415     6.50
# ...

# %% [markdown]
# ### Now let's turn `ABV` into a numeric data type
#
# Save the results back into the `ABV` column (again), and then check `df.dtypes` to make sure it worked.
#
# - *Tip: We used `.astype(int)` during class, but this has a decimal in it...*

# %%
df['ABV']= df.ABV.str.replace("%","").astype(float)
df.ABV
#Original Directions did not work
# Out:
# 0        4.5
# 1        4.9
# 2        4.8
# 3        6.0
# 4        6.0
# 5        5.6
# 6        8.0
# 7       12.5
# 8        7.7
# 9        4.2
# 10       5.0
# 11       6.6
# 12       4.0
# 13       5.5
# 14       7.6
# 15       5.1
# 16       6.5
# 17       6.0
# 18       5.0
# 19       5.2
# 20       4.8
# 21       7.2
# 22       6.7
# 23       4.9
# 24       8.0
# 25       7.5
# 26       6.0
# 27       8.0
# 28       6.3
# 29       5.8
#         ...
# 2386     5.7
# 2387     6.2
# 2388     4.9
# 2389     9.9
# 2390     6.2
# 2391     5.8
# 2392     5.2
# 2393     8.5
# 2394     7.0
# 2395     5.3
# 2396     5.6
# 2397     4.9
# 2398     5.1
# 2399     4.0
# 2400     5.5
# 2401     5.1
# 2402     5.1
# 2403     9.7
# 2404     5.1
# 2405     6.7
# 2406     6.2
# 2407     8.3
# 2408     7.0
# 2409     4.9
# 2410     9.9
# 2411     5.3
# 2412     9.9
# 2413     8.0
# 2414     8.7
# 2415     6.5
# Name: ABV, Length: 2416, dtype: float64

# %%
df.ABV
# Out:
# 0        4.5
# 1        4.9
# 2        4.8
# 3        6.0
# 4        6.0
# 5        5.6
# 6        8.0
# 7       12.5
# 8        7.7
# 9        4.2
# 10       5.0
# 11       6.6
# 12       4.0
# 13       5.5
# 14       7.6
# 15       5.1
# 16       6.5
# 17       6.0
# 18       5.0
# 19       5.2
# 20       4.8
# 21       7.2
# 22       6.7
# 23       4.9
# 24       8.0
# 25       7.5
# 26       6.0
# 27       8.0
# 28       6.3
# 29       5.8
#         ...
# 2386     5.7
# 2387     6.2
# 2388     4.9
# 2389     9.9
# 2390     6.2
# 2391     5.8
# 2392     5.2
# 2393     8.5
# 2394     7.0
# 2395     5.3
# 2396     5.6
# 2397     4.9
# 2398     5.1
# 2399     4.0
# 2400     5.5
# 2401     5.1
# 2402     5.1
# 2403     9.7
# 2404     5.1
# 2405     6.7
# 2406     6.2
# 2407     8.3
# 2408     7.0
# 2409     4.9
# 2410     9.9
# 2411     5.3
# 2412     9.9
# 2413     8.0
# 2414     8.7
# 2415     6.5
# Name: ABV, Length: 2416, dtype: float64

# %% [markdown]
# ## What's the ABV of the average beer look like?
#
# ### Show me in two different ways: one command to show the `median`/`mean`/etc, and secondly show me a chart

# %%
df.ABV.mean()
# Out:
# 5.977342419080068

# %%
df.ABV.describe()
# Out:
# count    2348.000000
# mean        5.977342
# std         1.354173
# min         0.100000
# 25%         5.000000
# 50%         5.600000
# 75%         6.700000
# max        12.800000
# Name: ABV, dtype: float64

# %%
df.ABV.head().plot()

# %% [markdown]
# ### We don't have ABV for all of the beers, how many are we missing them from?
#
# - *Tip: You can use `isnull()` or `notnull()` to see where a column is missing data.*
# - *Tip: You just want to count how many `True`s and `False`s there are.*
# - *Tip: It's a weird trick involving something we usually use to count things in a column*

# %%
df.ABV.isnull().value_counts(False)
# Out:
# False    2348
# True       68
# Name: ABV, dtype: int64

# %% [markdown]
# # Looking at location
#
# Brooklyn used to produce 80% of the country's beer! Let's see if it's still true.

# %% [markdown]
# ## What are the top 10 cities in the US for canned craft beer?

# %%
df.Location.value_counts().head(10)
# Out:
# Grand Rapids, MI    66
# Chicago, IL         55
# Portland, OR        52
# Indianapolis, IN    43
# San Diego, CA       42
# Boulder, CO         41
# Denver, CO          40
# Brooklyn, NY        38
# Seattle, WA         35
# Longmont, CO        33
# Name: Location, dtype: int64

# %% [markdown]
# ## List all of the beer from Brooklyn, NY

# %%
df[df.Location == 'Brooklyn, NY']
# Out:
#                                  Beer              Brewery      Location  \
# 115                            4Beans  Sixpoint Craft Ales  Brooklyn, NY
# 210                            Jammer  Sixpoint Craft Ales  Brooklyn, NY
# 246                           Abigale  Sixpoint Craft Ales  Brooklyn, NY
# 404                     Nomader Weiss    Evil Twin Brewing  Brooklyn, NY
# 421                               Rad  Sixpoint Craft Ales  Brooklyn, NY
# 439                      Molotov Lite    Evil Twin Brewing  Brooklyn, NY
# 588                           Bengali  Sixpoint Craft Ales  Brooklyn, NY
# 713                     Sensi Harvest  Sixpoint Craft Ales  Brooklyn, NY
# 969                            Hi-Res  Sixpoint Craft Ales  Brooklyn, NY
# 987             KelSo Nut Brown Lager   KelSo Beer Company  Brooklyn, NY
# 1057                    Global Warmer  Sixpoint Craft Ales  Brooklyn, NY
# 1074               Autumnation (2013)  Sixpoint Craft Ales  Brooklyn, NY
# ...

# %% [markdown]
# ## What brewery in Brooklyn puts out the most cans of beer?

# %%
df[df.Location == 'Brooklyn, NY']

# %%
df[df.Location == 'Brooklyn, NY'].sortby_value()
# Out:
# ------------------------------------------------------------------
# AttributeError                   Traceback (most recent call last)
# <ipython-input-61-0262ff268e45> in <module>()
# ----> 1 df[df.Location == 'Brooklyn, NY'].sortby_value()
#
# ~\AppData\Local\Programs\Python\Python36-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sortby_value'

# %% [markdown]
# ## What are the five most popular styles of beer produced by Sixpoint?

# %%
df[df.Brewery == 'Sixpoint Craft Ales'].sort_values(by='IBUs', ascending = False).head(5)
# Out:
#                     Beer              Brewery      Location  \
# 246              Abigale  Sixpoint Craft Ales  Brooklyn, NY
# 1624              3Beans  Sixpoint Craft Ales  Brooklyn, NY
# 1074  Autumnation (2013)  Sixpoint Craft Ales  Brooklyn, NY
# 1057       Global Warmer  Sixpoint Craft Ales  Brooklyn, NY
# 421                  Rad  Sixpoint Craft Ales  Brooklyn, NY
#
#                        Style    Size  ABV            IBUs
# 246         Belgian Pale Ale  12 oz.  8.0  Does not apply
# 1624           Baltic Porter  12 oz.  9.9              85
# 1074            American IPA  16 oz.  6.7              74
# 1057     American Strong Ale  12 oz.  7.0              70
# 421   Fruit / Vegetable Beer  16 oz.  3.2               7

# %% [markdown]
# ## List all of the breweries in New York state.
#
# - *Tip: We want to match *part* of the `Location` column, but not all of it.*
# - *Tip: Watch out for `NaN` values! You might be close, but you'll need to pass an extra parameter to make it work without an error.*

# %%
df[df.Location.str.contains(".*, NY", na=False)]
# Out:
#                                   Beer                     Brewery  \
# 115                             4Beans         Sixpoint Craft Ales
# 210                             Jammer         Sixpoint Craft Ales
# 246                            Abigale         Sixpoint Craft Ales
# 404                      Nomader Weiss           Evil Twin Brewing
# 421                                Rad         Sixpoint Craft Ales
# 439                       Molotov Lite           Evil Twin Brewing
# 588                            Bengali         Sixpoint Craft Ales
# 598                           8 Barrel             Chatham Brewing
# 599                        Oktoberfest             Chatham Brewing
# 628                          Cream Ale    Newburgh Brewing Company
# 653                      Montauk Light   Southampton Publick House
# 713                      Sensi Harvest         Sixpoint Craft Ales
# 768                 Montauk Summer Ale     Montauk Brewing Company
# ...

# %% [markdown]
# ### Now *count* all of the breweries in New York state

# %%
df[df.Location.str.contains(".*, NY", na=False)].describe()
# Out:
#              ABV
# count  73.000000
# mean    5.721918
# std     1.435100
# min     2.700000
# 25%     4.800000
# 50%     5.500000
# 75%     6.400000
# max    10.000000

# %% [markdown]
# # Measuring International Bitterness Units
#
# ## Display all of the IPAs
#
# Include American IPAs, Imperial IPAs, and anything else with "IPA in it."
#
# IPA stands for [India Pale Ale](https://www.bonappetit.com/story/ipa-beer-styles), and is probably the most popular kind of beer in the US for people who are drinking [craft beer](https://www.craftbeer.com/beer/what-is-craft-beer).

# %% [markdown]
# IPAs are usually pretty hoppy and bitter. IBU stands for [International Bitterness Unit](http://www.thebrewenthusiast.com/ibus/), and while a lot of places like to brag about having the most bitter beer (it's an American thing!), IBUs don't necessary *mean anything*.
#
# Let's look at how different beers have different IBU measurements.

# %% [markdown]
# ## Try to get the average IBU measurement across all beers

# %%
df.IBUs.mean()
# Out:
# ------------------------------------------------------------------
# TypeError                        Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python36-32\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     127                 else:
# --> 128                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     129             except Exception:
#
# ~\AppData\Local\Programs\Python\Python36-32\lib\site-packages\pandas\core\nanops.py in nanmean(values, axis, skipna)
#     354     count = _get_counts(mask, axis, dtype=dtype_count)
# --> 355     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     356
#
# ~\AppData\Local\Programs\Python\Python36-32\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims)
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#
# TypeError: must be str, not int
#
# ...

# %% [markdown]
# ### Oh no, it doesn't work!
#
# It looks like some of those values *aren't numbers*. There are two ways to fix this:
#
# 1. Do the `.replace` and `np.nan` thing we did in class. Then convert the column to a number. This is boring.
# 2. When you're reading in your csv, there [is an option called `na_values`](http://pandas.pydata.org/pandas-docs/version/0.23/generated/pandas.read_csv.html). You can give it a list of **numbers or strings to count as `NaN`**. It's a lot easier than doing the `np.nan` thing, although you'll need to go add it up top and run all of your cells again.
#
# - *Tip: Make sure you're giving `na_values` a LIST, not just a string*
#
# ### Now try to get the average IBUs again

# %%
df[df.IBUs.isnull()]
df.IBUs.replace("NaN", 0, inplace=True)

# %%
df[df.IBUs.isnull()]
df.IBUs.replace("Does not apply", 0, inplace=True)

# %% [markdown]
# ## Draw the distribution of IBU measurements, but with *twenty* bins instead of the default of 10
#
# - *Tip: Every time I ask for a distribution, I'm looking for a histogram*
# - *Tip: Use the `?` to get all of the options for building a histogram*
# - *Tip: Make sure your `matplotlib` thing is set up right!*

# %%
df.IBUs.head(20).hist()

# %% [markdown]
# ## Hm, Interesting distribution. List all of the beers with IBUs above the 75th percentile
#
# - *Tip: There's a single that gives you the 25/50/75th percentile*
# - *Tip: You can just manually type the number when you list those beers*

# %%
df[IBUs]=astype(int)
# Out:
# ------------------------------------------------------------------
# NameError                        Traceback (most recent call last)
# <ipython-input-131-3ae2d285db8e> in <module>()
# ----> 1 df[IBUs]=astype(int)
#
# NameError: name 'astype' is not defined

# %%
df.IBUs=df.IBUs.astype(float)

# %%
df.IBUs
# Out:
# 0        50.0
# 1        26.0
# 2        19.0
# 3        38.0
# 4        25.0
# 5        47.0
# 6        68.0
# 7        80.0
# 8        25.0
# 9        42.0
# 10       25.0
# 11       21.0
# 12       13.0
# 13       17.0
# 14       68.0
# 15       38.0
# 16        0.0
# 17       65.0
# 18       20.0
# 19       18.0
# 20       15.0
# 21       80.0
# 22       65.0
# 23       45.0
# 24      100.0
# 25       85.0
# 26       24.0
# 27      100.0
# 28       30.0
# 29       28.0
#         ...
# 2386     30.0
# 2387     65.0
# 2388      0.0
# 2389      0.0
# 2390     42.0
# 2391     35.0
# 2392     40.0
# 2393      0.0
# 2394    113.0
# 2395     21.0
# 2396     11.0
# 2397     44.0
# 2398     40.0
# 2399     37.0
# 2400     34.0
# 2401     45.0
# 2402     45.0
# 2403    120.0
# 2404     20.0
# 2405     33.0
# 2406     99.0
# 2407     35.0
# 2408     65.0
# 2409     17.0
# 2410     98.0
# 2411     35.0
# 2412    100.0
# 2413     35.0
# 2414     85.0
# 2415     65.0
# ...

# %%
df[df.IBUs < df.IBUs.quantile(.75)]
# Out:
#                                        Beer                        Brewery  \
# 1                             Maggie's Leap              NorthGate Brewing
# 2                                Wall's End              NorthGate Brewing
# 3                                   Pumpion              NorthGate Brewing
# 4                                Stronghold              NorthGate Brewing
# 8                                      35 K      Against the Grain Brewery
# 10                          Rules are Rules      Against the Grain Brewery
# 11                            Flesh Gourd'n      Against the Grain Brewery
# 12                                 Sho'nuff      Against the Grain Brewery
# 13                              Bloody Show      Against the Grain Brewery
# 15                         Coq de la Marche      Against the Grain Brewery
# 16                           Kamen Knuddeln      Against the Grain Brewery
# ...

# %%
df.dtypes
# Out:
# Beer         object
# Brewery      object
# Location     object
# Style        object
# Size         object
# ABV         float64
# IBUs         object
# dtype: object

# %% [markdown]
# ## List all of the beers with IBUs below the 25th percentile

# %%
df[df.IBUs < df.IBUs.quantile(.25)]
# Out:
# Empty DataFrame
# Columns: [Beer, Brewery, Location, Style, Size, ABV, IBUs]
# Index: []

# %% [markdown]
# ## List the median IBUs of each type of beer. Graph it.
#
# Put the highest at the top, and the missing ones at the bottom.
#
# - Tip: Look at the options for `sort_values` to figure out the `NaN` thing. The `?` probably won't help you here.

# %%
df.IBUs.median()
# Out:
# 18.0

# %%
df.groupby('Style').IBUs.median().plot(kind = 'barh')

# %% [markdown]
# ## Hmmmm, it looks like they are generally different styles. What are the most common 5 styles of high-IBU beer vs. low-IBU beer?
#
# - *Tip: You'll want to think about it in three pieces - filtering to only find the specific beers beers, then finding out what the most common styles are, then getting the top 5.*
# - *Tip: You CANNOT do this in one command. It's going to be one command for the high and one for the low.*
# - *Tip: "High IBU" means higher than 75th percentile, "Low IBU" is under 25th percentile*

# %%
df[df.IBUs < df.IBUs.quantile(.75)].groupby('Style').head(5)
# Out:
#                                        Beer  \
# 1                             Maggie's Leap
# 2                                Wall's End
# 3                                   Pumpion
# 4                                Stronghold
# 8                                      35 K
# 10                          Rules are Rules
# 11                            Flesh Gourd'n
# 12                                 Sho'nuff
# 13                              Bloody Show
# 15                         Coq de la Marche
# 16                           Kamen Knuddeln
# 18                           The Brown Note
# 19                              House Lager
# 20                             Leisure Time
# 26                                 Jucundus
# 28                                  Grazias
# 29                                 Claritas
# 30                                     Park
# 31                                Westfalia
# 32                                      KSA
# ...

# %%
df[df.IBUs > df.IBUs.quantile(.75)].groupby('Style').head(5)
# Out:
#                                                    Beer  \
# 0                                          Get Together
# 5                                           Parapet ESB
# 6                                        Citra Ass Down
# 7                                        London Balling
# 9                                                A Beer
# 14                                          Rico Sauvin
# 17                                         Pile of Face
# 21                                           Excess IPL
# 22                                       Hoponius Union
# 23                                             Calyptra
# 24                                       Habitus (2014)
# 25                                                Solis
# 27                                              Habitus
# 33                                             Villager
# 46                                  Yeti Imperial Stout
# 50                                            Dark Star
# ...

# %% [markdown]
# ## Get the average IBU of "Witbier", "Hefeweizen" and "American Pale Wheat Ale" styles
#
# I'm counting these as wheat beers. If you see any other wheat beer categories, feel free to include them. I want ONE measurement and ONE graph, not three separate ones. And 20 to 30 bins in the histogram, please.
#
# - *Tip: I hope that `isin` is in your toolbox*

# %%
df[df.Style.str.contains("Witbier", na=False)|df.Style.str.contains("Hefeweizen", na=False)|df.Style.str.contains("American Pale Wheat Ale", na=False)].mean()
# Out:
# ABV      5.043716
# IBUs    11.308511
# dtype: float64

# %% [markdown]
# ## Draw a histogram of the IBUs of those beers

# %%
df[df.Style.str.contains
("Witbier", na=False)|df.Style.str.contains
("Hefeweizen", na=False)|df.Style.str.contains
("American Pale Wheat Ale", na=False)].mean()
# Out:
# ABV      5.043716
# IBUs    11.308511
# dtype: float64

# %%
df[df.Style.str.contains("Witbier", na=False)|df.Style.str.contains("Hefeweizen", na=False)|df.Style.str.contains("American Pale Wheat Ale", na=False)].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x04A62F50>,
# ...
#       dtype=object)

# %%
df.IBUs.isin(thoseibus).mean()
# Out:
# 0.0

# %% [markdown]
# ## Get the average IBU of any style with "IPA" in it (also draw a histogram)

# %%
ax= df[df.Style.str.contains
("IPA", na=False)].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0B315E90>,
# ...
#       dtype=object)

# %% [markdown]
# ## Plot those two histograms on top of one another
#
# To plot two plots on top of one another, you do two steps.
#
# 1. First, you make a plot using `plot` or `hist`, and you save it into a variable called `ax`.
# 2. You draw your second graph using `plot` or `hist`, and send `ax=ax` to it as a parameter.
#
# It would look something like this:
#
# ```python
# ax = df.plot(....)
# df.plot(ax=ax, ....)
# ```
#
# (...except totally different)

# %%
ax= df[df.Style.str.contains
("IPA", na=False)].hist()

# %%
df[df.Style.str.contains("Witbier", na=False)|df.Style.str.contains("Hefeweizen", na=False)|df.Style.str.contains("American Pale Wheat Ale", na=False)].plot(ax=ax)
# Out:
# ------------------------------------------------------------------
# AttributeError                   Traceback (most recent call last)
# <ipython-input-225-b22e5c143dd0> in <module>()
# ----> 1 df[df.Style.str.contains("Witbier", na=False)|df.Style.str.contains("Hefeweizen", na=False)|df.Style.str.contains("American Pale Wheat Ale", na=False)].plot(ax=ax)
#
# ~\AppData\Local\Programs\Python\Python36-32\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ...

# %% [markdown]
# ## Compare the ABV of wheat beers vs. IPAs : their IBUs were really different, but how about their alcohol percentage?
#
# Wheat beers might include witbier, hefeweizen, American Pale Wheat Ale, and anything else you think is wheaty. IPAs probably have "IPA" in their name.

# %%
WheatB=df.ABV.isin(['witbier', 'hefeweizen', 'American Pale Wheat Ale'] )

# %%
df[df.Style.str.contains
("Witbier", na=False)|df.Style.str.contains
("Hefeweizen", na=False)|df.Style.str.contains
("American Pale Wheat Ale", na=False)].mean()
# Out:
# ABV      5.043716
# IBUs    11.308511
# dtype: float64

# %%
df[df.Style.str.contains
("IPA", na=False)].mean()
# Out:
# ABV      6.879286
# IBUs    49.394046
# dtype: float64

# %% [markdown]
# ## Good work!
#
# If you made it this far you deserve a drink.
